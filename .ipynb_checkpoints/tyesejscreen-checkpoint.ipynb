# %% [markdown]
# # TYES EJ SCREEN

# %% [markdown]
# This notebook is looking at environmental justice data for the TYES area, specifically pulling in indicators from the federal government's EJ SCREEN. Because it uses census-tract level data, we have identified specific California tracts that make up the TYES area at 1, 2 and 3 miles.

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import folium
import networkx as nx
import osmnx as ox
import contextily as ctx
from matplotlib.patches import Patch
from matplotlib.lines import Line2D

# %% [markdown]
# ### Geographic Data Pull ###

# %% [markdown]
# Here I am going to import EJ Screen Data for all of LA County, then I will specifically look at the areas that make up the census tracts in miles 1, 2, 3 for TYES. First, I will pull in GEOJSON Census Tract geographic data from: https://geohub.lacity.org/datasets/lacounty::census-tracts-2020/about

# %%
tracts=gpd.read_file('data/ct2020.geojson')
tracts.head()
# Out:
#    OBJECTID    CT20    LABEL   ShapeSTArea  ShapeSTLength  \
# 0      2496  101110  1011.10  1.229562e+07   15083.854287
# 1      2497  101122  1011.22  2.845774e+07   31671.455844
# 2      2498  101220  1012.20  7.522093e+06   12698.783810
# 3      2499  101221  1012.21  3.812000e+06    9161.710543
# 4      2500  101222  1012.22  3.191371e+06    9980.600461
#
#                                             geometry
# 0  POLYGON ((-118.29793 34.26323, -118.30082 34.2...
# 1  POLYGON ((-118.27743 34.25991, -118.27743 34.2...
# 2  POLYGON ((-118.27818 34.25577, -118.27887 34.2...
# 3  POLYGON ((-118.28735 34.25591, -118.28863 34.2...
# 4  POLYGON ((-118.28594 34.25590, -118.28697 34.2...

# %%
tracts = tracts[['CT20','geometry']]
tracts.head()
# Out:
#      CT20                                           geometry
# 0  101110  POLYGON ((-118.29793 34.26323, -118.30082 34.2...
# 1  101122  POLYGON ((-118.27743 34.25991, -118.27743 34.2...
# 2  101220  POLYGON ((-118.27818 34.25577, -118.27887 34.2...
# 3  101221  POLYGON ((-118.28735 34.25591, -118.28863 34.2...
# 4  101222  POLYGON ((-118.28594 34.25590, -118.28697 34.2...

# %%
tracts['FIPS'] ='06' + '037' + tracts['CT20']
tracts.head()
# Out:
#      CT20                                           geometry         FIPS
# 0  101110  POLYGON ((-118.29793 34.26323, -118.30082 34.2...  06037101110
# 1  101122  POLYGON ((-118.27743 34.25991, -118.27743 34.2...  06037101122
# 2  101220  POLYGON ((-118.27818 34.25577, -118.27887 34.2...  06037101220
# 3  101221  POLYGON ((-118.28735 34.25591, -118.28863 34.2...  06037101221
# 4  101222  POLYGON ((-118.28594 34.25590, -118.28697 34.2...  06037101222

# %% [markdown]
# ### Environmental Justice
#
#  I accessed federal data files from the EPA that include environmental justice indicators, but they needed to be filtered down to the tract level to not crash Jupyter Hub. I am going to read in and start to clean the EJ dataset.

# %%
ejca_full= pd.read_csv(
    'data/EJSCREEN_StatePct.csv',
    dtype=
    { 
        'ID':str
    }
)

# %%
ejca =ejca_full[ejca_full['CNTY_NAME'] == "Los Angeles"]

# %%
ejca
# Out:
#       OBJECTID           ID  STATE_NAME ST_ABBREV    CNTY_NAME  REGION  \
# 5584      5585  06037101110  California        CA  Los Angeles       9
# 5585      5586  06037101122  California        CA  Los Angeles       9
# 5586      5587  06037101220  California        CA  Los Angeles       9
# 5587      5588  06037101221  California        CA  Los Angeles       9
# 5588      5589  06037101222  California        CA  Los Angeles       9
# ...        ...          ...         ...       ...          ...     ...
# 8077      8078  06037980038  California        CA  Los Angeles       9
# 8078      8079  06037980039  California        CA  Los Angeles       9
# 8079      8080  06037990100  California        CA  Los Angeles       9
# 8080      8081  06037990200  California        CA  Los Angeles       9
# 8081      8082  06037990300  California        CA  Los Angeles       9
#
#       ACSTOTPOP  ACSIPOVBAS  ACSEDUCBAS  ACSTOTHH  ...  T_PTSDF_D2  T_UST_D2  \
# 5584     3923.0         NaN         NaN       NaN  ...     17 %ile    0 %ile
# 5585     4119.0         NaN         NaN       NaN  ...      9 %ile    0 %ile
# 5586     3775.0         NaN         NaN       NaN  ...     31 %ile    0 %ile
# 5587     3787.0         NaN         NaN       NaN  ...     23 %ile    0 %ile
# 5588     2717.0         NaN         NaN       NaN  ...     30 %ile    0 %ile
# ...         ...         ...         ...       ...  ...         ...       ...
# 8077        0.0         NaN         NaN       NaN  ...      0 %ile    0 %ile
# 8078        0.0         NaN         NaN       NaN  ...      0 %ile    0 %ile
# 8079        0.0         NaN         NaN       NaN  ...      0 %ile       NaN
# 8080        0.0         NaN         NaN       NaN  ...      0 %ile       NaN
# 8081        0.0         NaN         NaN       NaN  ...      0 %ile       NaN
#
#       T_PWDIS_D2  EXCEED_COUNT_80  AREALAND  AREAWATER  NPL_CNT  TSDF_CNT  \
# 5584         NaN              NaN       NaN        NaN      NaN       NaN
# 5585         NaN              NaN       NaN        NaN      NaN       NaN
# 5586         NaN              NaN       NaN        NaN      NaN       NaN
# 5587         NaN              NaN       NaN        NaN      NaN       NaN
# 5588         NaN              NaN       NaN        NaN      NaN       NaN
# ...          ...              ...       ...        ...      ...       ...
# 8077      0 %ile              NaN       NaN        NaN      NaN       NaN
# 8078         NaN              NaN       NaN        NaN      NaN       NaN
# 8079         NaN              NaN       NaN        NaN      NaN       NaN
# 8080         NaN              NaN       NaN        NaN      NaN       NaN
# 8081         NaN              NaN       NaN        NaN      NaN       NaN
#
#        Shape_Length    Shape_Area
# 5584    5565.411337  1.676519e+06
# 5585   11695.304395  3.881000e+06
# 5586    4688.607305  1.025452e+06
# 5587    3378.823980  5.197057e+05
# 5588    3685.233326  4.350619e+05
# ...             ...           ...
# 8077   15825.162592  6.588690e+06
# 8078    7196.703199  1.990662e+06
# 8079   92125.273156  2.520136e+08
# 8080  114705.298226  3.020180e+08
# 8081  109189.309695  2.076181e+08
#
# [2498 rows x 155 columns]

# %%
ejca.to_csv('data/ejca.csv')

# %%
ejca['FIPS']=ejca['ID']
ejca['FIPS']
# Out:
# /tmp/ipykernel_1609/2711271500.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ejca['FIPS']=ejca['ID']
# 5584    06037101110
# 5585    06037101122
# 5586    06037101220
# 5587    06037101221
# 5588    06037101222
#            ...
# 8077    06037980038
# 8078    06037980039
# 8079    06037990100
# 8080    06037990200
# 8081    06037990300
# Name: FIPS, Length: 2498, dtype: object

# %%
tyes_ej= tracts.merge(ejca,on='FIPS')

# %%
tyes_ej
# Out:
#         CT20                                           geometry         FIPS  \
# 0     101110  POLYGON ((-118.29793 34.26323, -118.30082 34.2...  06037101110
# 1     101122  POLYGON ((-118.27743 34.25991, -118.27743 34.2...  06037101122
# 2     101220  POLYGON ((-118.27818 34.25577, -118.27887 34.2...  06037101220
# 3     101221  POLYGON ((-118.28735 34.25591, -118.28863 34.2...  06037101221
# 4     101222  POLYGON ((-118.28594 34.25590, -118.28697 34.2...  06037101222
# ...      ...                                                ...          ...
# 2491  980031  MULTIPOLYGON (((-118.26315 33.76749, -118.2633...  06037980031
# 2492  980033  POLYGON ((-118.20551 33.78265, -118.20631 33.7...  06037980033
# 2493  599000  POLYGON ((-118.33083 33.35590, -118.33083 33.3...  06037599000
# 2494  599100  MULTIPOLYGON (((-118.60592 33.47890, -118.6059...  06037599100
# 2495  990300  MULTIPOLYGON (((-118.14232 33.73360, -118.1423...  06037990300
#
#       OBJECTID           ID  STATE_NAME ST_ABBREV    CNTY_NAME  REGION  \
# 0         5585  06037101110  California        CA  Los Angeles       9
# 1         5586  06037101122  California        CA  Los Angeles       9
# 2         5587  06037101220  California        CA  Los Angeles       9
# 3         5588  06037101221  California        CA  Los Angeles       9
# 4         5589  06037101222  California        CA  Los Angeles       9
# ...        ...          ...         ...       ...          ...     ...
# 2491      8072  06037980031  California        CA  Los Angeles       9
# 2492      8073  06037980033  California        CA  Los Angeles       9
# 2493      7644  06037599000  California        CA  Los Angeles       9
# 2494      7645  06037599100  California        CA  Los Angeles       9
# 2495      8082  06037990300  California        CA  Los Angeles       9
#
#       ACSTOTPOP  ...  T_PTSDF_D2  T_UST_D2  T_PWDIS_D2  EXCEED_COUNT_80  \
# 0        3923.0  ...     17 %ile    0 %ile         NaN              NaN
# 1        4119.0  ...      9 %ile    0 %ile         NaN              NaN
# 2        3775.0  ...     31 %ile    0 %ile         NaN              NaN
# 3        3787.0  ...     23 %ile    0 %ile         NaN              NaN
# 4        2717.0  ...     30 %ile    0 %ile         NaN              NaN
# ...         ...  ...         ...       ...         ...              ...
# 2491     1237.0  ...     58 %ile   69 %ile     22 %ile              NaN
# 2492       14.0  ...     97 %ile   98 %ile     99 %ile              NaN
# 2493     3696.0  ...      0 %ile   73 %ile         NaN              NaN
# 2494      710.0  ...      0 %ile   66 %ile         NaN              NaN
# 2495        0.0  ...      0 %ile       NaN         NaN              NaN
#
#       AREALAND  AREAWATER  NPL_CNT  TSDF_CNT   Shape_Length    Shape_Area
# 0          NaN        NaN      NaN       NaN    5565.411337  1.676519e+06
# 1          NaN        NaN      NaN       NaN   11695.304395  3.881000e+06
# 2          NaN        NaN      NaN       NaN    4688.607305  1.025452e+06
# 3          NaN        NaN      NaN       NaN    3378.823980  5.197057e+05
# 4          NaN        NaN      NaN       NaN    3685.233326  4.350619e+05
# ...        ...        ...      ...       ...            ...           ...
# 2491       NaN        NaN      NaN       NaN   30526.044346  3.762262e+07
# 2492       NaN        NaN      NaN       NaN   28538.578752  4.152819e+07
# 2493       NaN        NaN      NaN       NaN   11221.817411  5.523926e+06
# 2494       NaN        NaN      NaN       NaN  283589.506900  2.054634e+09
# 2495       NaN        NaN      NaN       NaN  109189.309695  2.076181e+08
#
# [2496 rows x 158 columns]

# %%
fig, ax = plt.subplots(figsize = (10,8)) 
tyes_ej.plot(column = 'MINORPCT',legend=True,
  legend_kwds={'orientation': "vertical"},classification_kwds={'bins':[0.25, 0.5,0.75,1]},cmap = 'PuBuGn',ax=ax)
ax.axis('off')
plt.title('Percentile Minority')
plt.savefig("Percentile Minority.png", transparent=True)
